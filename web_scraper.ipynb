# %% [markdown]
# ESPN API Scraper
# Men's Basketball

# %% [markdown]
# - Goal of this file is to scrape all games within specified time frame, then scrape boxscore data for BOTH teams from each unique game id.
# - Last update 02/02/26; having issues with too many requests
# - API Doumentation found thanks to https://gist.github.com/akeaswaran/b48b02f1c94f873c6655e7129910fc3b
#
# Specifically annotated to be shared with BYU Sports Analytics Association

# %%
import requests
import pandas as pd
from datetime import datetime

# %%
## set start and end dates of games to scrape
start_date = "20251104"
end_date = "20260131"

## create a date range. This will create a date for each day in the range.
dates = pd.date_range(
    start=datetime.strptime(start_date, "%Y%m%d"),
    end=datetime.strptime(end_date, "%Y%m%d")
)
# Out:
# DatetimeIndex(['2025-11-04', '2025-11-05', '2025-11-06', '2025-11-07',
#                '2025-11-08', '2025-11-09', '2025-11-10', '2025-11-11',
#                '2025-11-12', '2025-11-13', '2025-11-14', '2025-11-15',
#                '2025-11-16', '2025-11-17', '2025-11-18', '2025-11-19',
#                '2025-11-20', '2025-11-21', '2025-11-22', '2025-11-23',
#                '2025-11-24', '2025-11-25', '2025-11-26', '2025-11-27',
#                '2025-11-28', '2025-11-29', '2025-11-30', '2025-12-01',
#                '2025-12-02', '2025-12-03', '2025-12-04', '2025-12-05',
#                '2025-12-06', '2025-12-07', '2025-12-08', '2025-12-09',
#                '2025-12-10', '2025-12-11', '2025-12-12', '2025-12-13',
#                '2025-12-14', '2025-12-15', '2025-12-16', '2025-12-17',
#                '2025-12-18', '2025-12-19', '2025-12-20', '2025-12-21',
#                '2025-12-22', '2025-12-23', '2025-12-24', '2025-12-25',
#                '2025-12-26', '2025-12-27', '2025-12-28', '2025-12-29',
#                '2025-12-30', '2025-12-31', '2026-01-01', '2026-01-02',
#                '2026-01-03', '2026-01-04', '2026-01-05', '2026-01-06',
#                '2026-01-07', '2026-01-08', '2026-01-09', '2026-01-10',
#                '2026-01-11', '2026-01-12', '2026-01-13', '2026-01-14',
#                '2026-01-15', '2026-01-16', '2026-01-17', '2026-01-18',
#                '2026-01-19', '2026-01-20', '2026-01-21', '2026-01-22',
#                '2026-01-23', '2026-01-24', '2026-01-25', '2026-01-26',
#                '2026-01-27', '2026-01-28', '2026-01-29', '2026-01-30',
#                '2026-01-31'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# Quick explanation of APIs for those who are unfamiliar:
#
# **The basics:** An API is a tool that lets one program ask another program for data or perform an action. Instead of you manually finding and collecting information, you send a request to the API and it sends you back exactly what you need.
#
# **For your ESPN example:**
#
# The ESPN API allows your code to request college basketball game data without storing it yourself. Here's exactly what happens in this notebook:
#
# 1. **Request**: Your code sends a request to ESPN's API endpoint with parameters like:
#    - Date range (November 4, 2025 to January 31, 2026)
#    - `seasontype=2` (regular season games)
#    - `groups=50` (all Division 1 teams)
#    - `limit=1000` (get up to 1000 games per day)
#
# 2. **API Processing**: ESPN's servers receive your request and find all men's college basketball games matching those parameters
#
# 3. **Response**: ESPN sends back JSON data containing all the games for that date, including game IDs, teams, status, and more
#
# 4. **Your Code Extracts**: You parse through the response to pull out what you need—the game ID, teams playing, date, and game status—and store it in your `games` list
#
# So instead of manually looking up every college basketball game, the ESPN API does the heavy lifting and provides all the data in a structured format that your code can easily work with!

# %% [markdown]
# You CAN run out of requests when using an API, so we are going to not look at EVERY SINGLE GAME. Obviously, this may come with some limits. Feel free to experiment with how to pull data using the api and the amount to request at a time.

# %%
## dataframe of all games Nov 4, 2025 to Jan 31, 2026

# set up an empty list to hold game data
games = []

# loop through each date in the range and scrape game data
for date in dates:

    # api endpoint url with date parameter
    url = (
        "https://site.api.espn.com/apis/site/v2/sports/basketball/mens-college-basketball/scoreboard"
        f"?dates={date.strftime('%Y%m%d')}"
        ## need to include season type to get regular season games
        "&seasontype=2"
        ## need to include groups to get all D1 games
        "&groups=50"
        ## include ranked teams only false to get all games
        "&rankedTeamsOnly=false"
        ## increase limit to get all games in one request
        "&limit=1000"
    )

    ## make the request and parse the json response
    data = requests.get(url).json()
    ## the raw data returned will be stores in "keys" which you can somewhat see in the following code chunk. To access games, we need to look at the "events" key.
    for event in data.get('events', []):

        ## look at both teams' conferences
        competitors = event["competitions"][0]["competitors"]

        home = next(c for c in competitors if c["homeAway"] == "home")
        away = next(c for c in competitors if c["homeAway"] == "away")

        game_info = {
            "game_id": event['id'],
            "date": event['date'],
            "home_team": next(c['team']['displayName'] for c in event['competitions'][0]['competitors'] if c['homeAway'] == 'home'),
            "away_team": next(c['team']['displayName'] for c in event['competitions'][0]['competitors'] if c['homeAway'] == 'away'),
            "status": event['status']['type']['description']
        }
        games.append(game_info)

# %%
## explore the scraped data before parsing
print(data.keys())

## look at all the info stored within each key!
data['events'][0]
# Out:
# dict_keys(['leagues', 'groups', 'events', 'provider', 'eventsDate'])
# {'id': '401827652',
#  'uid': 's:40~l:41~e:401827652',
#  'date': '2026-01-31T19:00Z',
#  'name': 'Arizona Wildcats at Arizona State Sun Devils',
#  'shortName': 'ARIZ @ ASU',
#  'season': {'year': 2026, 'type': 2, 'slug': 'regular-season'},
#  'competitions': [{'id': '401827652',
#    'uid': 's:40~l:41~e:401827652~c:401827652',
#    'date': '2026-01-31T19:00Z',
#    'attendance': 13838,
#    'type': {'id': '1', 'abbreviation': 'STD'},
#    'timeValid': True,
#    'neutralSite': False,
#    'conferenceCompetition': True,
#    'playByPlayAvailable': True,
#    'recent': False,
#    'venue': {'id': '833',
#     'fullName': 'Desert Financial Arena',
#     'address': {'city': 'Tempe', 'state': 'AZ'},
#     'indoor': True},
#    'competitors': [{'id': '9',
#      'uid': 's:40~l:41~t:9',
#      'type': 'team',
#      'order': 0,
#      'homeAway': 'home',
#      'winner': False,
#      'team': {'id': '9',
#       'uid': 's:40~l:41~t:9',
#       'location': 'Arizona State',
#       'name': 'Sun Devils',
#       'abbreviation': 'ASU',
#       'displayName': 'Arizona State Sun Devils',
#       'shortDisplayName': 'Arizona St',
#       'color': 'ffc627',
#       'alternateColor': '8c1d40',
#       'isActive': True,
#       'venue': {'id': '833'},
#       'links': [{'rel': ['clubhouse', 'desktop', 'team'],
#         'href': 'https://www.espn.com/mens-college-basketball/team/_/id/9/arizona-state-sun-devils',
#         'text': 'Clubhouse',
#         'isExternal': False,
#         'isPremium': False},
#        {'rel': ['roster', 'desktop', 'team'],
#         'href': 'https://www.espn.com/mens-college-basketball/team/roster/_/id/9',
#         'text': 'Roster',
#         'isExternal': False,
#         'isPremium': False},
#        {'rel': ['stats', 'desktop', 'team'],
#         'href': 'https://www.espn.com/mens-college-basketball/team/stats/_/id/9',
#         'text': 'Statistics',
#         'isExternal': False,
#         'isPremium': False},
#        {'rel': ['schedule', 'desktop', 'team'],
#         'href': 'https://www.espn.com/mens-college-basketball/team/schedule/_/id/9',
#         'text': 'Schedule',
#         'isExternal': False,
#         'isPremium': False}],
#       'logo': 'https://a.espncdn.com/i/teamlogos/ncaa/500/9.png',
#       'conferenceId': '8'},
#      'score': '74',
#      'linescores': [{'value': 38.0, 'displayValue': '38', 'period': 1},
#       {'value': 36.0, 'displayValue': '36', 'period': 2}],
#      'statistics': [{'name': 'rebounds',
#        'abbreviation': 'REB',
#        'displayValue': '32'},
#       {'name': 'avgRebounds', 'abbreviation': 'REB', 'displayValue': '32.0'},
#       {'name': 'assists', 'abbreviation': 'AST', 'displayValue': '14'},
#       {'name': 'fieldGoalsAttempted',
#        'abbreviation': 'FGA',
#        'displayValue': '65'},
#       {'name': 'fieldGoalsMade', 'abbreviation': 'FGM', 'displayValue': '27'},
#       {'name': 'fieldGoalPct', 'abbreviation': 'FG%', 'displayValue': '41.5'},
#       {'name': 'freeThrowPct', 'abbreviation': 'FT%', 'displayValue': '60.0'},
#       {'name': 'freeThrowsAttempted',
#        'abbreviation': 'FTA',
#        'displayValue': '20'},
#       {'name': 'freeThrowsMade', 'abbreviation': 'FTM', 'displayValue': '12'},
#       {'name': 'points', 'abbreviation': 'PTS', 'displayValue': '74'},
#       {'name': 'threePointFieldGoalsAttempted',
#        'abbreviation': '3PA',
#        'displayValue': '24'},
#       {'name': 'threePointFieldGoalsMade',
#        'abbreviation': '3PM',
#        'displayValue': '8'},
#       {'name': 'avgPoints', 'abbreviation': 'PTS', 'displayValue': '74.0'},
#       {'name': 'avgAssists', 'abbreviation': 'AST', 'displayValue': '14.0'},
#       {'name': 'threePointFieldGoalPct',
#        'abbreviation': '3P%',
#        'displayValue': '33.3'}],
#      'leaders': [{'name': 'points',
#        'displayName': 'Points',
#        'shortDisplayName': 'Pts',
#        'abbreviation': 'Pts',
#        'leaders': [{'displayValue': '16',
#          'value': 16.0,
#          'athlete': {'id': '5311901',
#           'fullName': 'Noah Meeusen',
#           'displayName': 'Noah Meeusen',
#           'shortName': 'N. Meeusen',
#           'links': [{'rel': ['playercard', 'desktop', 'athlete'],
#             'href': 'https://www.espn.com/mens-college-basketball/player/_/id/5311901/noah-meeusen'}],
#           'headshot': 'https://a.espncdn.com/i/headshots/mens-college-basketball/players/full/5311901.png',
#           'jersey': '15',
#           'position': {'abbreviation': 'G'},
#           'team': {'id': '9'},
#           'active': True},
#          'team': {'id': '9'}}]},
#       {'name': 'rebounds',
#        'displayName': 'Rebounds',
#        'shortDisplayName': 'Reb',
#        'abbreviation': 'Reb',
#        'leaders': [{'displayValue': '7',
#          'value': 7.0,
#          'athlete': {'id': '5176444',
#           'fullName': 'Santiago Trouet',
#           'displayName': 'Santiago Trouet',
#           'shortName': 'S. Trouet',
#           'links': [{'rel': ['playercard', 'desktop', 'athlete'],
#             'href': 'https://www.espn.com/mens-college-basketball/player/_/id/5176444/santiago-trouet'}],
#           'headshot': 'https://a.espncdn.com/i/headshots/mens-college-basketball/players/full/5176444.png',
#           'jersey': '1',
#           'position': {'abbreviation': 'F'},
#           'team': {'id': '9'},
#           'active': True},
#          'team': {'id': '9'}}]},
#       {'name': 'assists',
#        'displayName': 'Assists',
#        'shortDisplayName': 'Ast',
#        'abbreviation': 'Ast',
#        'leaders': [{'displayValue': '5',
#          'value': 5.0,
#          'athlete': {'id': '5311901',
#           'fullName': 'Noah Meeusen',
#           'displayName': 'Noah Meeusen',
#           'shortName': 'N. Meeusen',
#           'links': [{'rel': ['playercard', 'desktop', 'athlete'],
#             'href': 'https://www.espn.com/mens-college-basketball/player/_/id/5311901/noah-meeusen'}],
#           'headshot': 'https://a.espncdn.com/i/headshots/mens-college-basketball/players/full/5311901.png',
#           'jersey': '15',
#           'position': {'abbreviation': 'G'},
#           'team': {'id': '9'},
#           'active': True},
#          'team': {'id': '9'}}]},
#       {'name': 'rating',
#        'displayName': 'Rating',
#        'shortDisplayName': 'RAT',
#        'abbreviation': 'RAT',
#        'leaders': [{'displayValue': '16 PTS, 3 STL',
#          'value': 30.75,
#          'athlete': {'id': '5311901',
#           'fullName': 'Noah Meeusen',
#           'displayName': 'Noah Meeusen',
#           'shortName': 'N. Meeusen',
#           'links': [{'rel': ['playercard', 'desktop', 'athlete'],
#             'href': 'https://www.espn.com/mens-college-basketball/player/_/id/5311901/noah-meeusen'}],
#           'headshot': 'https://a.espncdn.com/i/headshots/mens-college-basketball/players/full/5311901.png',
#           'jersey': '15',
#           'position': {'abbreviation': 'G'},
#           'team': {'id': '9'},
#           'active': True},
#          'team': {'id': '9'}}]}],
#      'curatedRank': {'current': 99},
#      'records': [{'name': 'overall',
#        'abbreviation': 'Game',
#        'type': 'total',
#        'summary': '11-11'},
#       {'name': 'Home', 'type': 'home', 'summary': '6-5'},
#       {'name': 'Road', 'type': 'road', 'summary': '1-5'},
#       {'name': 'vs. Conf.', 'type': 'vsconf', 'summary': '2-7'}]},
#     {'id': '12',
#      'uid': 's:40~l:41~t:12',
#      'type': 'team',
#      'order': 1,
#      'homeAway': 'away',
#      'winner': True,
#      'team': {'id': '12',
#       'uid': 's:40~l:41~t:12',
#       'location': 'Arizona',
#       'name': 'Wildcats',
#       'abbreviation': 'ARIZ',
#       'displayName': 'Arizona Wildcats',
#       'shortDisplayName': 'Arizona',
#       'color': 'cc0033',
#       'alternateColor': '003366',
#       'isActive': True,
#       'venue': {'id': '1064'},
#       'links': [{'rel': ['clubhouse', 'desktop', 'team'],
#         'href': 'https://www.espn.com/mens-college-basketball/team/_/id/12/arizona-wildcats',
#         'text': 'Clubhouse',
#         'isExternal': False,
#         'isPremium': False},
#        {'rel': ['roster', 'desktop', 'team'],
#         'href': 'https://www.espn.com/mens-college-basketball/team/roster/_/id/12',
#         'text': 'Roster',
#         'isExternal': False,
#         'isPremium': False},
#        {'rel': ['stats', 'desktop', 'team'],
#         'href': 'https://www.espn.com/mens-college-basketball/team/stats/_/id/12',
#         'text': 'Statistics',
#         'isExternal': False,
#         'isPremium': False},
#        {'rel': ['schedule', 'desktop', 'team'],
#         'href': 'https://www.espn.com/mens-college-basketball/team/schedule/_/id/12',
#         'text': 'Schedule',
#         'isExternal': False,
#         'isPremium': False}],
#       'logo': 'https://a.espncdn.com/i/teamlogos/ncaa/500/12.png',
#       'conferenceId': '8'},
#      'score': '87',
#      'linescores': [{'value': 38.0, 'displayValue': '38', 'period': 1},
#       {'value': 49.0, 'displayValue': '49', 'period': 2}],
#      'statistics': [{'name': 'rebounds',
#        'abbreviation': 'REB',
#        'displayValue': '47'},
#       {'name': 'avgRebounds', 'abbreviation': 'REB', 'displayValue': '47.0'},
#       {'name': 'assists', 'abbreviation': 'AST', 'displayValue': '17'},
#       {'name': 'fieldGoalsAttempted',
#        'abbreviation': 'FGA',
#        'displayValue': '63'},
#       {'name': 'fieldGoalsMade', 'abbreviation': 'FGM', 'displayValue': '32'},
#       {'name': 'fieldGoalPct', 'abbreviation': 'FG%', 'displayValue': '50.8'},
#       {'name': 'freeThrowPct', 'abbreviation': 'FT%', 'displayValue': '73.1'},
#       {'name': 'freeThrowsAttempted',
#        'abbreviation': 'FTA',
#        'displayValue': '26'},
#       {'name': 'freeThrowsMade', 'abbreviation': 'FTM', 'displayValue': '19'},
#       {'name': 'points', 'abbreviation': 'PTS', 'displayValue': '87'},
#       {'name': 'threePointFieldGoalsAttempted',
#        'abbreviation': '3PA',
#        'displayValue': '11'},
#       {'name': 'threePointFieldGoalsMade',
#        'abbreviation': '3PM',
#        'displayValue': '4'},
#       {'name': 'avgPoints', 'abbreviation': 'PTS', 'displayValue': '87.0'},
#       {'name': 'avgAssists', 'abbreviation': 'AST', 'displayValue': '17.0'},
#       {'name': 'threePointFieldGoalPct',
#        'abbreviation': '3P%',
#        'displayValue': '36.4'}],
#      'leaders': [{'name': 'points',
#        'displayName': 'Points',
#        'shortDisplayName': 'Pts',
#        'abbreviation': 'Pts',
#        'leaders': [{'displayValue': '21',
#          'value': 21.0,
#          'athlete': {'id': '5041953',
#           'fullName': 'Koa Peat',
#           'displayName': 'Koa Peat',
#           'shortName': 'K. Peat',
#           'links': [{'rel': ['playercard', 'desktop', 'athlete'],
#             'href': 'https://www.espn.com/mens-college-basketball/player/_/id/5041953/koa-peat'}],
#           'headshot': 'https://a.espncdn.com/i/headshots/mens-college-basketball/players/full/5041953.png',
#           'jersey': '10',
#           'position': {'abbreviation': 'F'},
#           'team': {'id': '12'},
#           'active': True},
#          'team': {'id': '12'}}]},
#       {'name': 'rebounds',
#        'displayName': 'Rebounds',
#        'shortDisplayName': 'Reb',
#        'abbreviation': 'Reb',
#        'leaders': [{'displayValue': '13',
#          'value': 13.0,
#          'athlete': {'id': '5105555',
#           'fullName': 'Tobe Awaka',
#           'displayName': 'Tobe Awaka',
#           'shortName': 'T. Awaka',
#           'links': [{'rel': ['playercard', 'desktop', 'athlete'],
#             'href': 'https://www.espn.com/mens-college-basketball/player/_/id/5105555/tobe-awaka'}],
#           'headshot': 'https://a.espncdn.com/i/headshots/mens-college-basketball/players/full/5105555.png',
#           'jersey': '30',
#           'position': {'abbreviation': 'F'},
#           'team': {'id': '12'},
#           'active': True},
#          'team': {'id': '12'}}]},
#       {'name': 'assists',
#        'displayName': 'Assists',
#        'shortDisplayName': 'Ast',
#        'abbreviation': 'Ast',
#        'leaders': [{'displayValue': '6',
#          'value': 6.0,
#          'athlete': {'id': '4432737',
#           'fullName': 'Jaden Bradley',
#           'displayName': 'Jaden Bradley',
#           'shortName': 'J. Bradley',
#           'links': [{'rel': ['playercard', 'desktop', 'athlete'],
#             'href': 'https://www.espn.com/mens-college-basketball/player/_/id/4432737/jaden-bradley'}],
#           'headshot': 'https://a.espncdn.com/i/headshots/mens-college-basketball/players/full/4432737.png',
#           'jersey': '0',
#           'position': {'abbreviation': 'G'},
#           'team': {'id': '12'},
#           'active': True},
#          'team': {'id': '12'}}]},
#       {'name': 'rating',
#        'displayName': 'Rating',
#        'shortDisplayName': 'RAT',
#        'abbreviation': 'RAT',
#        'leaders': [{'displayValue': '17 PTS, 7 REB',
#          'value': 33.20000076293945,
#          'athlete': {'id': '5082206',
#           'fullName': 'Brayden Burries',
#           'displayName': 'Brayden Burries',
#           'shortName': 'B. Burries',
#           'links': [{'rel': ['playercard', 'desktop', 'athlete'],
#             'href': 'https://www.espn.com/mens-college-basketball/player/_/id/5082206/brayden-burries'}],
#           'headshot': 'https://a.espncdn.com/i/headshots/mens-college-basketball/players/full/5082206.png',
#           'jersey': '5',
#           'position': {'abbreviation': 'G'},
#           'team': {'id': '12'},
#           'active': True},
#          'team': {'id': '12'}}]}],
#      'curatedRank': {'current': 1},
#      'records': [{'name': 'overall',
#        'abbreviation': 'Game',
#        'type': 'total',
#        'summary': '22-0'},
#       {'name': 'Home', 'type': 'home', 'summary': '12-0'},
#       {'name': 'Road', 'type': 'road', 'summary': '6-0'},
#       {'name': 'vs. Conf.', 'type': 'vsconf', 'summary': '9-0'}]}],
#    'notes': [],
#    'status': {'clock': 0.0,
#     'displayClock': '0:00',
#     'period': 2,
#     'type': {'id': '3',
#      'name': 'STATUS_FINAL',
#      'state': 'post',
#      'completed': True,
#      'description': 'Final',
#      'detail': 'Final',
#      'shortDetail': 'Final'}},
#    'broadcasts': [{'market': 'national', 'names': ['TNT']}],
#    'groups': {'id': '8',
#     'name': 'Big 12 Conference',
#     'shortName': 'Big 12',
#     'isConference': True},
#    'format': {'regulation': {'periods': 2}},
#    'startDate': '2026-01-31T19:00Z',
#    'broadcast': 'TNT',
#    'geoBroadcasts': [{'type': {'id': '1', 'shortName': 'TV'},
#      'market': {'id': '1', 'type': 'National'},
#      'media': {'shortName': 'TNT'},
#      'lang': 'en',
#      'region': 'us'}],
#    'highlights': [],
#    'headlines': [{'type': 'Recap',
#      'description': '— Koa Peat scored 21 points, fellow freshman Brayden Burries added 17 and No. 1 Arizona beat rival Arizona State 87-74 on Saturday, setting a school record with 22 straight wins to...',
#      'shortLinkText': 'No. 1 Arizona sets school record with 22nd straight win to start season, beating Arizona State 87-74'}]}],
#  'links': [{'language': 'en-US',
#    'rel': ['summary', 'desktop', 'event'],
#    'href': 'https://www.espn.com/mens-college-basketball/game/_/gameId/401827652/arizona-arizona-st',
#    'text': 'Gamecast',
#    'shortText': 'Gamecast',
#    'isExternal': False,
#    'isPremium': False},
#   {'language': 'en-US',
#    'rel': ['boxscore', 'desktop', 'event'],
#    'href': 'https://www.espn.com/mens-college-basketball/boxscore/_/gameId/401827652',
#    'text': 'Box Score',
#    'shortText': 'Box Score',
#    'isExternal': False,
#    'isPremium': False},
#   {'language': 'en-US',
#    'rel': ['pbp', 'desktop', 'event'],
#    'href': 'https://www.espn.com/mens-college-basketball/playbyplay/_/gameId/401827652',
#    'text': 'Play-by-Play',
#    'shortText': 'Play-by-Play',
#    'isExternal': False,
#    'isPremium': False},
#   {'language': 'en-US',
#    'rel': ['recap', 'desktop', 'event'],
#    'href': 'https://www.espn.com/mens-college-basketball/recap?gameId=401827652',
#    'text': 'Recap',
#    'shortText': 'Recap',
#    'isExternal': False,
#    'isPremium': False}],
#  'status': {'clock': 0.0,
#   'displayClock': '0:00',
#   'period': 2,
#   'type': {'id': '3',
#    'name': 'STATUS_FINAL',
#    'state': 'post',
#    'completed': True,
#    'description': 'Final',
#    'detail': 'Final',
#    'shortDetail': 'Final'}}}

# %%
## create a dataframe from the list of games
games_df = pd.DataFrame(games)
games_df
# Out:
#         game_id               date                      home_team  \
# 0     401828553  2025-11-04T23:30Z            Purdue Boilermakers
# 1     401817228  2025-11-05T01:45Z               Duke Blue Devils
# 2     401826746  2025-11-05T00:00Z              Kentucky Wildcats
# 3     401819898  2025-11-05T01:00Z         Texas Tech Red Raiders
# 4     401826052  2025-11-04T23:00Z                UMBC Retrievers
# ...         ...                ...                            ...
# 4147  401829330  2026-02-01T03:00Z        San José State Spartans
# 4148  401829223  2026-02-01T03:00Z             San Francisco Dons
# 4149  401808507  2026-02-01T03:00Z       Sacramento State Hornets
# 4150  401804908  2026-02-01T03:05Z           Sam Houston Bearkats
# 4151  401829287  2026-01-31T21:30Z  South Carolina State Bulldogs
#
#                           away_team     status
# 0            Evansville Purple Aces      Final
# 1                   Texas Longhorns      Final
# 2                 Nicholls Colonels      Final
# 3                  Lindenwood Lions      Final
# 4     Penn State-York Nittany Lions      Final
# ...                             ...        ...
# 4147               New Mexico Lobos      Final
# 4148                 Pacific Tigers      Final
# 4149              Montana Grizzlies      Final
# 4150        Louisiana Tech Bulldogs      Final
# 4151  North Carolina Central Eagles  Postponed
#
# [4152 rows x 5 columns]

# %% [markdown]
# Now we want to use this data frame of every game_id to create a huge dataset of boxscores. First lets make sure we only include completed games, as well as see if we can only include the conferences we are interested in for this particular analysis. We will be scraping again, so the smaller the dataset the better, just because it is possible to run out of requests!

# %%
## drop if game is equal to postponed or canceled
games_df = games_df[~games_df['status'].isin(['Postponed', 'Canceled'])]

print(games_df['status'].value_counts())

print(games_df['game_id'].nunique())
# Out:
# status
# Final    4135
# Name: count, dtype: int64
# 4135

# %%
## create a lookup dictionary for team conferences
team_lookup = {}

for event in data.get("events", []):  # loop over the events list
    comp = event["competitions"][0]
    conf = comp.get("groups", {}).get("shortName", None)

    # get both team names
    home = next(c for c in comp["competitors"] if c["homeAway"] == "home")["team"]["displayName"]
    away = next(c for c in comp["competitors"] if c["homeAway"] == "away")["team"]["displayName"]

    # assign conference to both teams
    team_lookup[home] = conf
    team_lookup[away] = conf

team_lookup
# Out:
# {'Arizona State Sun Devils': 'Big 12',
#  'Arizona Wildcats': 'Big 12',
#  'Creighton Bluejays': 'Big East',
#  'UConn Huskies': 'Big East',
#  'Virginia Tech Hokies': 'ACC',
#  'Duke Blue Devils': 'ACC',
#  'Gonzaga Bulldogs': 'WCC',
#  "Saint Mary's Gaels": 'WCC',
#  'Houston Cougars': 'Big 12',
#  'Cincinnati Bearcats': 'Big 12',
#  'UCF Knights': 'Big 12',
#  'Texas Tech Red Raiders': 'Big 12',
#  'Kansas Jayhawks': 'Big 12',
#  'BYU Cougars': 'Big 12',
#  'Arkansas Razorbacks': 'SEC',
#  'Kentucky Wildcats': 'SEC',
#  'Georgia Tech Yellow Jackets': 'ACC',
#  'North Carolina Tar Heels': 'ACC',
#  'Boston College Eagles': 'ACC',
#  'Virginia Cavaliers': 'ACC',
#  'Vanderbilt Commodores': 'SEC',
#  'Ole Miss Rebels': 'SEC',
#  'Louisville Cardinals': 'ACC',
#  'SMU Mustangs': 'ACC',
#  'Clemson Tigers': 'ACC',
#  'Pittsburgh Panthers': 'ACC',
#  'Miami (OH) RedHawks': 'MAC',
#  'Northern Illinois Huskies': 'MAC',
#  'Winthrop Eagles': 'Big South',
#  'UNC Asheville Bulldogs': 'Big South',
#  'Seton Hall Pirates': 'Big East',
#  'Marquette Golden Eagles': 'Big East',
#  'Butler Bulldogs': 'Big East',
#  'Georgetown Hoyas': 'Big East',
#  'Wake Forest Demon Deacons': 'ACC',
#  'NC State Wolfpack': 'ACC',
#  'Toledo Rockets': 'MAC',
#  'Ball State Cardinals': 'MAC',
#  'William & Mary Tribe': 'CAA',
#  'Campbell Fighting Camels': 'CAA',
#  'Elon Phoenix': 'CAA',
#  'Stony Brook Seawolves': 'CAA',
#  'The Citadel Bulldogs': 'SoCon',
#  'UNC Greensboro Spartans': 'SoCon',
#  'Indiana State Sycamores': 'MVC',
#  'Valparaiso Beacons': 'MVC',
#  'Army Black Knights': 'Patriot',
#  'Holy Cross Crusaders': 'Patriot',
#  'Utah State Aggies': 'Mountain West',
#  'San Diego State Aztecs': 'Mountain West',
#  'Xavier Musketeers': 'Big East',
#  'DePaul Blue Demons': 'Big East',
#  'Purdue Fort Wayne Mastodons': 'Horizon',
#  'Robert Morris Colonials': 'Horizon',
#  'Le Moyne Dolphins': 'NEC',
#  'Stonehill Skyhawks': 'NEC',
#  'Wagner Seahawks': 'NEC',
#  'Fairleigh Dickinson Knights': 'NEC',
#  'South Carolina Gamecocks': 'SEC',
#  'LSU Tigers': 'SEC',
#  'Georgia Bulldogs': 'SEC',
#  'Texas A&M Aggies': 'SEC',
#  'Lehigh Mountain Hawks': 'Patriot',
#  'Colgate Raiders': 'Patriot',
#  'American University Eagles': 'Patriot',
#  'Lafayette Leopards': 'Patriot',
#  'George Washington Revolutionaries': 'A-10',
#  'Fordham Rams': 'A-10',
#  'Wisconsin Badgers': 'Big Ten',
#  'Ohio State Buckeyes': 'Big Ten',
#  'Bucknell Bison': 'Patriot',
#  'Boston University Terriers': 'Patriot',
#  'Presbyterian Blue Hose': 'Big South',
#  'Radford Highlanders': 'Big South',
#  'Chicago State Cougars': 'NEC',
#  'Mercyhurst Lakers': 'NEC',
#  'Buffalo Bulls': 'MAC',
#  'Ohio Bobcats': 'MAC',
#  'Central Connecticut Blue Devils': 'NEC',
#  'Long Island University Sharks': 'NEC',
#  'UMass Lowell River Hawks': 'Am. East',
#  'Maine Black Bears': 'Am. East',
#  'Northeastern Huskies': 'CAA',
#  'Charleston Cougars': 'CAA',
#  'Drexel Dragons': 'CAA',
#  'North Carolina A&T Aggies': 'CAA',
#  'Towson Tigers': 'CAA',
#  'Hampton Pirates': 'CAA',
#  'Monmouth Hawks': 'CAA',
#  'Hofstra Pride': 'CAA',
#  'Mercer Bears': 'SoCon',
#  'VMI Keydets': 'SoCon',
#  'Texas State Bobcats': 'Sun Belt',
#  'Old Dominion Monarchs': 'Sun Belt',
#  'Oklahoma Sooners': 'SEC',
#  'Texas Longhorns': 'SEC',
#  'Bellarmine Knights': 'ASUN',
#  'Queens University Royals': 'ASUN',
#  'Stetson Hatters': 'ASUN',
#  'North Alabama Lions': 'ASUN',
#  'North Florida Ospreys': 'ASUN',
#  'Lipscomb Bisons': 'ASUN',
#  'La Salle Explorers': 'A-10',
#  "Saint Joseph's Hawks": 'A-10',
#  'Longwood Lancers': 'Big South',
#  'High Point Panthers': 'Big South',
#  'Air Force Falcons': 'Mountain West',
#  'Fresno State Bulldogs': 'Mountain West',
#  'South Dakota State Jackrabbits': 'Summit',
#  'Oral Roberts Golden Eagles': 'Summit',
#  'Arkansas State Red Wolves': 'Sun Belt',
#  'Marshall Thundering Herd': 'Sun Belt',
#  'Southern Miss Golden Eagles': 'Sun Belt',
#  'James Madison Dukes': 'Sun Belt',
#  'Weber State Wildcats': 'Big Sky',
#  'Idaho State Bengals': 'Big Sky',
#  'Jacksonville Dolphins': 'ASUN',
#  'Florida Gulf Coast Eagles': 'ASUN',
#  'UT Arlington Mavericks': 'WAC',
#  'California Baptist Lancers': 'WAC',
#  'Missouri State Bears': 'CUSA',
#  'Jacksonville State Gamecocks': 'CUSA',
#  'Alabama State Hornets': 'SWAC',
#  'Bethune-Cookman Wildcats': 'SWAC',
#  'Missouri Tigers': 'SEC',
#  'Mississippi State Bulldogs': 'SEC',
#  'Morehead State Eagles': 'OVC',
#  'Lindenwood Lions': 'OVC',
#  'Northern Iowa Panthers': 'MVC',
#  'Evansville Purple Aces': 'MVC',
#  'Howard Bison': 'MEAC',
#  'Norfolk State Spartans': 'MEAC',
#  'West Virginia Mountaineers': 'Big 12',
#  'Baylor Bears': 'Big 12',
#  'Mississippi Valley State Delta Devils': 'SWAC',
#  'Arkansas-Pine Bluff Golden Lions': 'SWAC',
#  'Jackson State Tigers': 'SWAC',
#  'Grambling Tigers': 'SWAC',
#  'Miami Hurricanes': 'ACC',
#  'California Golden Bears': 'ACC',
#  'Navy Midshipmen': 'Patriot',
#  'Loyola Maryland Greyhounds': 'Patriot',
#  'Denver Pioneers': 'Summit',
#  'Omaha Mavericks': 'Summit',
#  'Bryant Bulldogs': 'Am. East',
#  'New Hampshire Wildcats': 'Am. East',
#  'Long Beach State Beach': 'Big West',
#  "Hawai'i Rainbow Warriors": 'Big West',
#  "Louisiana Ragin' Cajuns": 'Sun Belt',
#  'Georgia Southern Eagles': 'Sun Belt',
#  'Northern Colorado Bears': 'Big Sky',
#  'Eastern Washington Eagles': 'Big Sky',
#  'Abilene Christian Wildcats': 'WAC',
#  'Southern Utah Thunderbirds': 'WAC',
#  'Middle Tennessee Blue Raiders': 'CUSA',
#  'Western Kentucky Hilltoppers': 'CUSA',
#  'Tennessee Tech Golden Eagles': 'OVC',
#  'Little Rock Trojans': 'OVC',
#  'Richmond Spiders': 'A-10',
#  'Davidson Wildcats': 'A-10',
#  'Coppin State Eagles': 'MEAC',
#  'Morgan State Bears': 'MEAC',
#  'Texas A&M-Corpus Christi Islanders': 'Southland',
#  'Houston Christian Huskies': 'Southland',
#  'Vermont Catamounts': 'Am. East',
#  'NJIT Highlanders': 'Am. East',
#  'Troy Trojans': 'Sun Belt',
#  'App State Mountaineers': 'Sun Belt',
#  'Central Arkansas Bears': 'ASUN',
#  'Eastern Kentucky Colonels': 'ASUN',
#  'West Georgia Wolves': 'ASUN',
#  'Austin Peay Governors': 'ASUN',
#  'Western Illinois Leathernecks': 'OVC',
#  'UT Martin Skyhawks': 'OVC',
#  'Eastern Illinois Panthers': 'OVC',
#  'Southeast Missouri State Redhawks': 'OVC',
#  'Alcorn State Braves': 'SWAC',
#  'Southern Jaguars': 'SWAC',
#  'Delaware State Hornets': 'MEAC',
#  'Maryland Eastern Shore Hawks': 'MEAC',
#  'UCLA Bruins': 'Big Ten',
#  'Indiana Hoosiers': 'Big Ten',
#  'Cal State Bakersfield Roadrunners': 'Big West',
#  'UC Davis Aggies': 'Big West',
#  'Incarnate Word Cardinals': 'Southland',
#  'UT Rio Grande Valley Vaqueros': 'Southland',
#  'Portland State Vikings': 'Big Sky',
#  'Montana State Bobcats': 'Big Sky',
#  'Tarleton State Texans': 'WAC',
#  'Utah Tech Trailblazers': 'WAC',
#  'Kennesaw State Owls': 'CUSA',
#  'New Mexico State Aggies': 'CUSA',
#  'Prairie View A&M Panthers': 'SWAC',
#  'Texas Southern Tigers': 'SWAC',
#  'Alabama A&M Bulldogs': 'SWAC',
#  'Florida A&M Rattlers': 'SWAC',
#  'Drake Bulldogs': 'MVC',
#  'Bradley Braves': 'MVC',
#  'Washington State Cougars': 'WCC',
#  'Portland Pilots': 'WCC',
#  'San Diego Toreros': 'WCC',
#  'Oregon State Beavers': 'WCC',
#  'Syracuse Orange': 'ACC',
#  'Notre Dame Fighting Irish': 'ACC',
#  'Brown Bears': 'Ivy',
#  'Dartmouth Big Green': 'Ivy',
#  'Columbia Lions': 'Ivy',
#  'Princeton Tigers': 'Ivy',
#  'South Dakota Coyotes': 'Summit',
#  'North Dakota State Bison': 'Summit',
#  'Massachusetts Minutemen': 'MAC',
#  'Eastern Michigan Eagles': 'MAC',
#  'Cornell Big Red': 'Ivy',
#  'Pennsylvania Quakers': 'Ivy',
#  'Stephen F. Austin Lumberjacks': 'Southland',
#  'SE Louisiana Lions': 'Southland',
#  'New Orleans Privateers': 'Southland',
#  'Northwestern State Demons': 'Southland',
#  'East Texas A&M Lions': 'Southland',
#  'Nicholls Colonels': 'Southland',
#  'Utah Utes': 'Big 12',
#  'Oklahoma State Cowboys': 'Big 12',
#  'Florida State Seminoles': 'ACC',
#  'Stanford Cardinal': 'ACC',
#  'St. Bonaventure Bonnies': 'A-10',
#  'George Mason Patriots': 'A-10',
#  'Southern Illinois Salukis': 'MVC',
#  'UIC Flames': 'MVC',
#  'USC Trojans': 'Big Ten',
#  'Rutgers Scarlet Knights': 'Big Ten',
#  'Central Michigan Chippewas': 'MAC',
#  'Bowling Green Falcons': 'MAC',
#  'Yale Bulldogs': 'Ivy',
#  'Harvard Crimson': 'Ivy',
#  'Saint Francis Red Flash': 'NEC',
#  'New Haven Chargers': 'NEC',
#  'UAlbany Great Danes': 'Am. East',
#  'UMBC Retrievers': 'Am. East',
#  'Lamar Cardinals': 'Southland',
#  'McNeese Cowboys': 'Southland',
#  'Belmont Bruins': 'MVC',
#  'Murray State Racers': 'MVC',
#  'North Texas Mean Green': 'American',
#  'UAB Blazers': 'American',
#  'Northwestern Wildcats': 'Big Ten',
#  'Washington Huskies': 'Big Ten',
#  'UC Riverside Highlanders': 'Big West',
#  'Cal Poly Mustangs': 'Big West',
#  'Cal State Northridge Matadors': 'Big West',
#  'UC San Diego Tritons': 'Big West',
#  'South Alabama Jaguars': 'Sun Belt',
#  'Georgia State Panthers': 'Sun Belt',
#  'Northern Arizona Lumberjacks': 'Big Sky',
#  'Idaho Vandals': 'Big Sky',
#  'Temple Owls': 'American',
#  'South Florida Bulls': 'American',
#  'Southern Indiana Screaming Eagles': 'OVC',
#  'SIU Edwardsville Cougars': 'OVC',
#  'Tennessee Volunteers': 'SEC',
#  'Auburn Tigers': 'SEC',
#  'Loyola Marymount Lions': 'WCC',
#  'Santa Clara Broncos': 'WCC',
#  'UC Santa Barbara Gauchos': 'Big West',
#  'Cal State Fullerton Titans': 'Big West',
#  'UTEP Miners': 'CUSA',
#  'Delaware Blue Hens': 'CUSA',
#  'Wyoming Cowboys': 'Mountain West',
#  'Colorado State Rams': 'Mountain West',
#  'San José State Spartans': 'Mountain West',
#  'New Mexico Lobos': 'Mountain West',
#  'San Francisco Dons': 'WCC',
#  'Pacific Tigers': 'WCC',
#  'Sacramento State Hornets': 'Big Sky',
#  'Montana Grizzlies': 'Big Sky',
#  'Sam Houston Bearkats': 'CUSA',
#  'Louisiana Tech Bulldogs': 'CUSA',
#  'South Carolina State Bulldogs': 'MEAC',
#  'North Carolina Central Eagles': 'MEAC'}

# %%
## add conference info to the dataframe
games_df["home_conf"] = games_df["home_team"].map(team_lookup)
games_df["away_conf"] = games_df["away_team"].map(team_lookup)

games_df
# Out:
#         game_id               date                      home_team  \
# 0     401828553  2025-11-04T23:30Z            Purdue Boilermakers
# 1     401817228  2025-11-05T01:45Z               Duke Blue Devils
# 2     401826746  2025-11-05T00:00Z              Kentucky Wildcats
# 3     401819898  2025-11-05T01:00Z         Texas Tech Red Raiders
# 4     401826052  2025-11-04T23:00Z                UMBC Retrievers
# ...         ...                ...                            ...
# 4147  401829330  2026-02-01T03:00Z        San José State Spartans
# 4148  401829223  2026-02-01T03:00Z             San Francisco Dons
# 4149  401808507  2026-02-01T03:00Z       Sacramento State Hornets
# 4150  401804908  2026-02-01T03:05Z           Sam Houston Bearkats
# 4151  401829287  2026-01-31T21:30Z  South Carolina State Bulldogs
#
#                           away_team     status      home_conf      away_conf
# 0            Evansville Purple Aces      Final            NaN            MVC
# 1                   Texas Longhorns      Final            ACC            SEC
# 2                 Nicholls Colonels      Final            SEC      Southland
# 3                  Lindenwood Lions      Final         Big 12            OVC
# 4     Penn State-York Nittany Lions      Final       Am. East            NaN
# ...                             ...        ...            ...            ...
# 4147               New Mexico Lobos      Final  Mountain West  Mountain West
# 4148                 Pacific Tigers      Final            WCC            WCC
# 4149              Montana Grizzlies      Final        Big Sky        Big Sky
# 4150        Louisiana Tech Bulldogs      Final           CUSA           CUSA
# 4151  North Carolina Central Eagles  Postponed           MEAC           MEAC
#
# [4152 rows x 7 columns]

# %%
## filter games to only include those with teams from conferences of interest
conferences_of_interest = ["ACC", "Big East", "Big Ten", "Big 12", "SEC", "Pac-12", "A-10", "WCC", "Horizon", "MVC", "Colonial", "MAC", "MWC", "C-USA"]

filtered_games_df = games_df[
    (games_df["home_conf"].isin(conferences_of_interest)) |
    (games_df["away_conf"].isin(conferences_of_interest))
].reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/env386/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'home_conf'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 5
#       1 ## filter games to only include those with teams from conferences of interest
#       2 conferences_of_interest = ["ACC", "Big East", "Big Ten", "Big 12", "SEC", "Pac-12", "A-10", "WCC", "Horizon", "MVC", "Colonial", "MAC", "MWC", "C-USA"]
#       4 filtered_games_df = games_df[
# ----> 5     (games_df["home_conf"].isin(conferences_of_interest)) |
#       6     (games_df["away_conf"].isin(conferences_of_interest))
#       7 ].reset_index(drop=True)
#
# File /opt/anaconda3/envs/env386/lib/python3.12/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File /opt/anaconda3/envs/env386/lib/python3.12/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'home_conf'
